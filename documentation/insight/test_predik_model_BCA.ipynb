# %% [markdown]
# ### PEMBUKTIAN ATAU PENGETESAN MODEL MACHINE LEARNING BCA
#
# Menggunakan model prediksi saham BCA yang sudah ada di folder models pada file model_prediksi_saham_BCA.pkl, saya akan melakukan dokumentasi atau pembuktian apakah model yang saya temukan akurat dan worth digunakan untuk melakukan prediksi.

# %%
import os
print(os.getcwd())
# Out:
# d:\Data Gerald\alphaflow-by-gerald\documentation\insight

# %%
from IPython.display import Image, display

display(Image(filename='../images/malea_BCA.png', width=400))

# %% [markdown]
# #### Penjelasan:
# Menggunakan model ML dari model_prediksi_saham_BCA.pkl, model mendapatkan bahwa esok hari 06/01/2026 saham Bank BCA akan berada di angka Rp 8,052.67 dengan dini hari 05/01/2026 angka harga saham Bank BCA berada di Rp 8,075 (Adj. Close).

# %%
from IPython.display import Image, display

display(Image(filename='../images/doc_BCA.png', width=500))

# %% [markdown]
# #### Tambahan:
# Sesuai dengan gambar, bahwasannya memang benar bahwa harga saham Bank BCA dini hari 05/01/2026 adalah Rp 8,075. Dengan itu, saya akan cek besok kembali bagaimana hasil dari modelnya dan menilainya kembali.
#
# ---

# %% [markdown]
# #### Laporan 06/01/2026
#
# - Perihal    : Harga Saham Bank BCA
# - Model      : model_prediksi_saham_BCA.pkl in models
# - Catatan    : latihan_prediksi_saham_BCA.ipynb in notebooks
# - App        : app_prediksi_saham_BCA.py
# - Tools      : folder src
#
# ---

# %%
from IPython.display import Image, display

display(Image(filename='../images/doc_BCA_06_01.png', width=500))

# %% [markdown]
# #### Kesimpulan:
#
# Ternyata, mesin saat ini tidak mampu untuk mendeteksi perubahan secara akurat. Hal itu terjadi karena model yang dihasilkan adalah model dari metode Regresi Linear yang penerapannya, tidak mampu membaca lonjakan atau GAP yang akurat. Sehingga, model ini bukanlah model yang salah maupun benar, tetapi, dari sini kita bisa belajar bahwa model yang dihasilkan mesin dari metode Regresi Linear, tidak terlalu worth it untuk digunakan dalam konteks prediksi harga saham.
